# %%
import sys
import os

# Add the project root directory to sys.path
project_dir = os.path.dirname(os.getcwd())
sys.path.append(project_dir)

# %%
from axiom.mdata.account import get_account_hash, get_account_info, get_account_transactions

# %%
account_hash = await get_account_hash()
# account_hash

# %%
accounts = await get_account_info()
# accounts

# %%
transactions = await get_account_transactions()
# transactions[:25]
